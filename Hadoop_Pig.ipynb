# %% [markdown]
# <a href="https://colab.research.google.com/github/v-Shivaprasad/Hadoop-Hive-Pig-Environment-in-Colab/blob/main/Hadoop_Pig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y openjdk-8-jdk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libgail-common libgail18 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common librsvg2-common libxcomposite1 libxt-dev
#   libxtst6 libxxf86dga1 openjdk-8-jdk-headless openjdk-8-jre
#   openjdk-8-jre-headless session-migration x11-utils
# Suggested packages:
#   gvfs libxt-doc openjdk-8-demo openjdk-8-source visualvm libnss-mdns
#   fonts-nanum fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
# ...

# %%
# !java -version
# Out:
# openjdk version "17.0.17" 2025-10-21
# OpenJDK Runtime Environment (build 17.0.17+10-Ubuntu-122.04)
# OpenJDK 64-Bit Server VM (build 17.0.17+10-Ubuntu-122.04, mixed mode, sharing)

# %%
# !wget https://archive.apache.org/dist/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# !tar -xzf hadoop-3.3.6.tar.gz
# Out:
# --2026-01-02 09:17:00--  https://archive.apache.org/dist/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M  9.89MB/s    in 2m 15s
#
# 2026-01-02 09:19:15 (5.17 MB/s) - ‘hadoop-3.3.6.tar.gz’ saved [730107476/730107476]

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["HADOOP_HOME"] = "/content/hadoop-3.3.6"
os.environ["PATH"] += ":/content/hadoop-3.3.6/bin:/content/hadoop-3.3.6/sbin"

# %%
# !sed -i 's|${JAVA_HOME}|/usr/lib/jvm/java-8-openjdk-amd64|' $HADOOP_HOME/etc/hadoop/hadoop-env.sh

# %%
# !ls /content
# Out:
# hadoop-3.3.6  hadoop-3.3.6.tar.gz  sample_data

# %%
# !ls /content/hadoop-3.3.6/etc/hadoop
# Out:
# capacity-scheduler.xml		  kms-log4j.properties
# configuration.xsl		  kms-site.xml
# container-executor.cfg		  log4j.properties
# core-site.xml			  mapred-env.cmd
# hadoop-env.cmd			  mapred-env.sh
# hadoop-env.sh			  mapred-queues.xml.template
# hadoop-metrics2.properties	  mapred-site.xml
# hadoop-policy.xml		  shellprofile.d
# hadoop-user-functions.sh.example  ssl-client.xml.example
# hdfs-rbf-site.xml		  ssl-server.xml.example
# hdfs-site.xml			  user_ec_policies.xml.template
# httpfs-env.sh			  workers
# httpfs-log4j.properties		  yarn-env.cmd
# httpfs-site.xml			  yarn-env.sh
# kms-acls.xml			  yarnservice-log4j.properties
# kms-env.sh			  yarn-site.xml

# %%
# %%writefile /content/hadoop-3.3.6/etc/hadoop/core-site.xml
# <configuration>
#  <property>
#   <name>fs.defaultFS</name>
#   <value>hdfs://localhost:9000</value>
#  </property>
# </configuration>
# Out:
# Overwriting /content/hadoop-3.3.6/etc/hadoop/core-site.xml

# %%
# %%writefile /content/hadoop-3.3.6/etc/hadoop/hdfs-site.xml
# <configuration>
#  <property>
#   <name>dfs.replication</name>
#   <value>1</value>
#  </property>
# </configuration>
# Out:
# Overwriting /content/hadoop-3.3.6/etc/hadoop/hdfs-site.xml

# %%
# %%writefile /content/hadoop-3.3.6/etc/hadoop/workers
# localhost
# Out:
# Overwriting /content/hadoop-3.3.6/etc/hadoop/workers

# %% [markdown]
# # HADOOP SETUP COMPLETE

# %%
# !nohup hdfs namenode > nn.log 2>&1 &

# %%
# !nohup hdfs datanode > dn.log 2>&1 &

# %%
# !jps
# Out:
# 2950 Jps
# 1688 NameNode
# 1723 DataNode

# %%
# !hdfs dfs -mkdir -p /user/root

# %% [markdown]
# #**TEMP TRIAL PLAY**

# %%
# !hdfs dfs -mkdir -p /user/root

# %%
# !hdfs dfs -ls /
# Out:
# Found 2 items
# drwxr-xr-x   - root supergroup          0 2026-01-02 09:20 /college
# drwxr-xr-x   - root supergroup          0 2026-01-02 09:22 /user

# %%
# !hdfs dfs -mkdir /user/root/shiva

# %%
# !hdfs dfs -ls /user/root
# Out:
# Found 1 items
# drwxr-xr-x   - root supergroup          0 2026-01-02 09:22 /user/root/shiva

# %%
# %%writefile file.txt
# hola mi amigo como estas
# Out:
# Overwriting file.txt

# %% [markdown]
# **Put file**

# %%
# !hdfs dfs -put file.txt /user/root/shiva

# %%
# !hdfs dfs -ls /user/root/shiva
# Out:
# Found 1 items
# -rw-r--r--   1 root supergroup         25 2026-01-02 09:22 /user/root/shiva/file.txt

# %% [markdown]
# **GET FILE**

# %%
# !hdfs dfs -get /user/root/shiva/file.txt ./hadooppppp.txt
# Out:
# get: `/user/root/shiva/file.txt': No such file or directory

# %%
# %%writefile copy-example.txt
# YE raatein ye mausam nadee ka kinaara ye chanchal hawa
# Out:
# Writing copy-example.txt

# %%
# !pwd
# Out:
# /content

# %%
# !hdfs dfs -put /content/copy-example.txt /user/root/shiva/
# Out:
# put: `/user/root/shiva/': No such file or directory: `hdfs://localhost:9000/user/root/shiva'

# %%
# !hdfs dfs -cp /user/root/shiva/copy-example.txt /user/root/
# Out:
# cp: `/user/root/': No such file or directory: `hdfs://localhost:9000/user/root'

# %%
# !hdfs dfs -ls /user/root/shiva
# Out:
# ls: `/user/root/shiva': No such file or directory

# %%
# !hdfs dfs -cat /user/root/shiva/copy-example.txt
# Out:
# cat: `/user/root/shiva/copy-example.txt': No such file or directory

# %% [markdown]
# ##PLAY COMPLETE

# %% [markdown]
# ##LAB

# %%
# !mkdir test

# %%
# !cd test

# %%
# %%writefile subject1
# OS,DBMS,ML
# Out:
# Writing subject1

# %%
# %%writefile subject2
# Hadoop,Pig,Hive
# Out:
# Writing subject2

# %%
# %%writefile subject3
# Arch,Colab,BigData
# Out:
# Writing subject3

# %%
# !ls
# !cat subject1
# Out:
# copy-example.txt  hadoop-3.3.6	       sample_data  subject3
# dn.log		  hadoop-3.3.6.tar.gz  subject1     test
# file.txt	  nn.log	       subject2
# OS,DBMS,ML

# %%
# !cd test

# %%
# !hdfs dfs -mkdir /college

# %%
# !hdfs dfs -mkdir /college/cse
# !hdfs dfs -mkdir /college/ece

# %% [markdown]
# ##**3. Copy Local Files to HDFS**

# %%
# !hdfs dfs -put subject1 /college/cse
# !hdfs dfs -put subject2 /college/cse
# !hdfs dfs -put subject3 /college/cse

# %%
# !hdfs dfs -ls /college/cse
# Out:
# Found 2 items
# -rw-r--r--   1 root supergroup         11 2026-01-02 09:25 /college/cse/subject1
# -rw-r--r--   1 root supergroup         16 2026-01-02 09:25 /college/cse/subject2

# %% [markdown]
# #**4. Copy Files Between HDFS Directories**

# %%
# !hdfs dfs -cp /college/cse/subject1 /college/ece
# !hdfs dfs -cp /college/cse/subject2 /college/ece

# %%
# !hdfs dfs -ls /college/ece
# Out:
# Found 3 items
# -rw-r--r--   1 root supergroup         11 2026-01-02 09:25 /college/ece/subject1
# -rw-r--r--   1 root supergroup         16 2026-01-02 09:26 /college/ece/subject2
# -rw-r--r--   1 root supergroup         19 2026-01-02 09:25 /college/ece/subject3

# %% [markdown]
# #**5. Move a File**

# %%
# !hdfs dfs -mv /college/cse/subject3 /college/ece

# %%
# !hdfs dfs -ls /college/cse
# Out:
# Found 2 items
# -rw-r--r--   1 root supergroup         11 2026-01-02 09:25 /college/cse/subject1
# -rw-r--r--   1 root supergroup         16 2026-01-02 09:25 /college/cse/subject2

# %%
# !hdfs dfs -ls /college/ece
# Out:
# Found 3 items
# -rw-r--r--   1 root supergroup         11 2026-01-02 09:25 /college/ece/subject1
# -rw-r--r--   1 root supergroup         16 2026-01-02 09:26 /college/ece/subject2
# -rw-r--r--   1 root supergroup         19 2026-01-02 09:25 /college/ece/subject3

# %% [markdown]
# #**Remove Specific Files and Directories**

# %%
# !hdfs dfs -rm /college/cse/subject2
# Out:
# Deleted /college/cse/subject2

# %%
# !hdfs dfs -ls /college/cse
# Out:
# Found 1 items
# -rw-r--r--   1 root supergroup         11 2026-01-02 09:25 /college/cse/subject1

# %%
# !hdfs dfs -rm -r /college/ece
# Out:
# Deleted /college/ece

# %% [markdown]
# IfyReally care idc

# %% [markdown]
# #**Word count application using Mapper Reducer on single node cluster**

# %%
# %%writefile WordCountMapper.java
# import java.io.IOException;
# import org.apache.hadoop.io.*;
# import org.apache.hadoop.mapreduce.Mapper;
# public class WordCountMapper extends Mapper<LongWritable, Text, Text, LongWritable> {
#  public void map(LongWritable key, Text value, Context context) throws IOException,
# InterruptedException {
#  String words[] = value.toString().split(" "); // Split the input line into words
#  for (int i = 0; i < words.length; i++) {
#  context.write(new Text(words[i]), new LongWritable(1)); // Emit word and count
#  }
#  }
# }
# Out:
# Overwriting WordCountMapper.java

# %%
# %%writefile WordCountReducer.java
# import java.io.IOException;
# import org.apache.hadoop.io.*;
# import org.apache.hadoop.mapreduce.Reducer;
# public class WordCountReducer extends Reducer<Text, LongWritable, Text, LongWritable> {
#  public void reduce(Text key, Iterable<LongWritable> values, Context context) throws IOException,
# InterruptedException {
#  long sum = 0;
#  for (LongWritable val : values) {
#  sum += val.get(); // Sum the counts for each word
#  }
#  context.write(key, new LongWritable(sum)); // Emit word and total count
#  }
# }
# Out:
# Overwriting WordCountReducer.java

# %%
# %%writefile WordCountDriver.java
# import java.io.IOException;
# import org.apache.hadoop.fs.Path;
# import org.apache.hadoop.io.LongWritable;
# import org.apache.hadoop.io.Text;
# import org.apache.hadoop.mapreduce.Job;
# import org.apache.hadoop.mapreduce.lib.input.FileInputFormat;
# import org.apache.hadoop.mapreduce.lib.output.FileOutputFormat;
# public class WordCountDriver {
#  public static void main(String s[]) throws IOException, ClassNotFoundException,
# InterruptedException {
#  if (s.length != 2) {
#  System.err.println("2 arguments required: <input path> <output path>");
#  System.exit(-1);
#  }
#  @SuppressWarnings("deprecation")
#  Job job = new Job();
#  job.setJarByClass(WordCountDriver.class);
#  job.setJobName("WordCount");
#  FileInputFormat.addInputPath(job, new Path(s[0])); // Input path
#  FileOutputFormat.setOutputPath(job, new Path(s[1])); // Output path
#  job.setMapperClass(WordCountMapper.class);
#  // job.setCombinerClass(TransposeCombiner.class); // Optional combiner
#  job.setReducerClass(WordCountReducer.class);
#  job.setOutputKeyClass(Text.class);
#  job.setOutputValueClass(LongWritable.class);
#
#  System.exit(job.waitForCompletion(true) ? 0 : 1); // Submit job and wait for completion
#  }
# }
# Out:
# Overwriting WordCountDriver.java

# %%
# !javac --release 8 -cp "$(hadoop classpath)" -d . WordCountMapper.java WordCountReducer.java WordCountDriver.java

# %%
# !jar -cvf WordCount.jar -C . .
# Out:
# Streaming output truncated to the last 5000 lines.
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/FuncUtils.html(in = 4446) (out= 1156)(deflated 73%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/FunctionWrapperEvalFunc.html(in = 4600) (out= 1164)(deflated 74%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/GenericInvoker.html(in = 7585) (out= 1571)(deflated 79%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/GetDay.html(in = 4413) (out= 1153)(deflated 73%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/GetHour.html(in = 4424) (out= 1153)(deflated 73%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/GetMilliSecond.html(in = 4501) (out= 1158)(deflated 74%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/GetMinute.html(in = 4446) (out= 1156)(deflated 73%)
# adding: pig-0.17.0/docs/api/org/apache/pig/builtin/class-use/GetMonth.html(in = 4435) (out= 1153)(deflated 74%)
# ...

# %%
# %%writefile input.txt
# Helloo This is a test file all codes copied
# Out:
# Overwriting input.txt

# %%
# !hdfs dfs -put input.txt /user/root/shiva/

# %%
# !hadoop jar WordCount.jar WordCountDriver /user/root/shiva/input.txt /user/root/shiva/output
# Out:
# 2026-01-02 10:52:26,743 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2026-01-02 10:52:26,956 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2026-01-02 10:52:26,956 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2026-01-02 10:52:27,207 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.
# 2026-01-02 10:52:58,009 INFO input.FileInputFormat: Total input files to process : 1
# 2026-01-02 10:52:58,112 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-01-02 10:52:58,409 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1850736512_0001
# 2026-01-02 10:52:58,409 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-01-02 10:52:58,627 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# ...

# %%
# !hdfs dfs -cat /user/root/shiva/output/part-r-00000
# Out:
# Helloo	1
# This	1
# a	1
# all	1
# codes	1
# copied	1
# file	1
# is	1
# test	1

# %%
# !hdfs dfs -mkdir -p /user/hadoop

# %%
# %%writefile HDFS.java
# import org.apache.hadoop.conf.Configuration;
# import org.apache.hadoop.fs.FileSystem;
# import org.apache.hadoop.fs.Path;
# import org.apache.hadoop.fs.FSDataOutputStream;
#
# public class HDFS {
#   public static void main(String[] args) throws Exception {
#
#     Configuration conf = new Configuration();
#     FileSystem fs = FileSystem.get(conf);
#
#     Path writePath = new Path("/user/hadoop/hdfsfile.txt");
#     Path copyPath  = new Path("/user/hadoop/hdfsfile_copy.txt");
#
#     // WRITE (must close stream)
#     FSDataOutputStream out = fs.create(writePath, true);
#     out.write("Hello, HDFS!".getBytes());
#     out.close();
#
#     // READ
#     byte[] data = new byte[(int) fs.getFileStatus(writePath).getLen()];
#     fs.open(writePath).readFully(0, data);
#     System.out.println(new String(data));
#
#     // HDFS → HDFS COPY (NOT copyToLocalFile)
#     fs.rename(writePath, copyPath);
#
#     // CLEANUP
#     fs.delete(writePath, true);
#     fs.delete(copyPath, true);
#
#     fs.close();
#   }
# }
# Out:
# Overwriting HDFS.java

# %%
# !!hadoop classpath | head
# Out:
# ['/content/hadoop-3.3.6/etc/hadoop:/content/hadoop-3.3.6/share/hadoop/common/lib/*:/content/hadoop-3.3.6/share/hadoop/common/*:/content/hadoop-3.3.6/share/hadoop/hdfs:/content/hadoop-3.3.6/share/hadoop/hdfs/lib/*:/content/hadoop-3.3.6/share/hadoop/hdfs/*:/content/hadoop-3.3.6/share/hadoop/mapreduce/*:/content/hadoop-3.3.6/share/hadoop/yarn:/content/hadoop-3.3.6/share/hadoop/yarn/lib/*:/content/hadoop-3.3.6/share/hadoop/yarn/*']

# %%
# !javac -cp "$(hadoop classpath)" HDFS.java

# %%
# !java -cp ".:$(hadoop classpath)" HDFS
# Out:
# 2026-01-02 09:51:07,811 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Hello, HDFS!

# %% [markdown]
# #**PIG**

# %%
# %%writefile emp4.txt
# 101,John,50000,1
# 102,Alice,60000,2
# 103,Bob,55000,1
# 104,Charlie,70000,3
# 105,David,48000,2
# Out:
# Writing emp4.txt

# %%
# !hdfs dfs -ls
# Out:
# Found 1 items
# drwxr-xr-x   - root supergroup          0 2026-01-02 09:22 shiva

# %%
# !hdfs dfs -put emp4.txt /user/root/shiva/

# %%
# !wget https://archive.apache.org/dist/pig/pig-0.17.0/pig-0.17.0.tar.gz
# !tar -xzf pig-0.17.0.tar.gz
# Out:
# --2026-01-02 09:55:23--  https://archive.apache.org/dist/pig/pig-0.17.0/pig-0.17.0.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 230606579 (220M) [application/x-gzip]
# Saving to: ‘pig-0.17.0.tar.gz’
#
# pig-0.17.0.tar.gz   100%[===================>] 219.92M  14.8MB/s    in 16s
#
# 2026-01-02 09:55:39 (14.2 MB/s) - ‘pig-0.17.0.tar.gz’ saved [230606579/230606579]

# %%
# !export PIG_HOME=/content/pig-0.17.0
# !export PATH=$PATH:/content/pig-0.17.0/bin

# %%
# !/content/pig-0.17.0/bin/pig -version
# Out:
# Apache Pig version 0.17.0 (r1797386)
# compiled Jun 02 2017, 15:41:58

# %% [markdown]
# a = load 'emp4.txt' using PigStorage(',') as (eno: int, ename: chararray, sal: int, did: int);
#
# 4. Display the Data
#
#
# dump a;
#
# Output:
# (101,John,50000,1)
#
# (102,Alice,60000,2)
#
# (103,Bob,55000,1)
#
# (104,Charlie,70000,3)
#
# (105,David,48000,2)
#
# (,,,)
#
# 5. Group the Data for Aggregation:
#
# grouped_data = group a all;
#
# 6. Calculate the Average Salary:
#
# avg_salary = foreach grouped_data generate AVG(a.sal);
#
# 7. Display the Average Salary:
#
# dump avg_salary;

# %% [markdown]
# # **PigShell**

# %%
# !/content/pig-0.17.0/bin/pig -x mapreduce
# Out:
# 2026-01-02 09:58:23,348 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2026-01-02 09:58:23,353 INFO pig.ExecTypeProvider: Trying ExecType : MAPREDUCE
# 2026-01-02 09:58:23,355 INFO pig.ExecTypeProvider: Picked MAPREDUCE as the ExecType
# 2026-01-02 09:58:23,573 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2026-01-02 09:58:23,573 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1767347903560.log
# 2026-01-02 09:58:23,602 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2026-01-02 09:58:24,397 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2026-01-02 09:58:24,398 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: hdfs://localhost:9000
# ...

# %%
# %%writefile passwords.txt
# Rama,R12345,root
# Krishna,K53412,superuser
# Suresh,T5342s3,root
# Laxmi, L43t56*,superuser
# Out:
# Overwriting passwords.txt

# %%
# !hdfs dfs -put passwords.txt /user/root/shiva/passwords.txt

# %%
# !/content/pig-0.17.0/bin/pig -x mapreduce
# Out:
# 2026-01-02 10:09:04,763 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2026-01-02 10:09:04,765 INFO pig.ExecTypeProvider: Trying ExecType : MAPREDUCE
# 2026-01-02 10:09:04,765 INFO pig.ExecTypeProvider: Picked MAPREDUCE as the ExecType
# 2026-01-02 10:09:04,884 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2026-01-02 10:09:04,884 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1767348544874.log
# 2026-01-02 10:09:04,913 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2026-01-02 10:09:05,427 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2026-01-02 10:09:05,427 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: hdfs://localhost:9000
# ...

# %%
# %%writefile test1.txt
# 1,john,70000,1
# 2,hari,70848,2
# 3,ramu,69489,2
# 4,teju,97582,1
# 5,shiva,79050,2
# 6,giri,58170,1
# 7,raju,89792,2
# 8,bindu,80802,1
# 9,sindhu,70179,2
# 10,vicky,87982,1
# Out:
# Overwriting test1.txt

# %%
# !hdfs dfs -ls /user/root/shiva
# Out:
# Found 4 items
# -rw-r--r--   1 root supergroup         89 2026-01-02 09:54 /user/root/shiva/emp4.txt
# -rw-r--r--   1 root supergroup         25 2026-01-02 09:22 /user/root/shiva/file.txt
# -rw-r--r--   1 root supergroup         87 2026-01-02 10:06 /user/root/shiva/passwords.txt
# -rw-r--r--   1 root supergroup        156 2026-01-02 10:19 /user/root/shiva/test1.txt

# %%
# !hdfs dfs -put test1.txt /user/root/shiva/

# %%
# !wget https://archive.apache.org/dist/hive/hive-2.3.9/apache-hive-2.3.9-bin.tar.gz
# !tar -xzf apache-hive-2.3.9-bin.tar.gz
# Out:
# --2026-01-02 10:20:51--  https://archive.apache.org/dist/hive/hive-2.3.9/apache-hive-2.3.9-bin.tar.gz
# Resolving archive.apache.org (archive.apache.org)... 65.108.204.189, 2a01:4f9:1a:a084::2
# Connecting to archive.apache.org (archive.apache.org)|65.108.204.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 286170958 (273M) [application/x-gzip]
# Saving to: ‘apache-hive-2.3.9-bin.tar.gz’
#
# apache-hive-2.3.9-b 100%[===================>] 272.91M  18.6MB/s    in 28s
#
# 2026-01-02 10:21:20 (9.58 MB/s) - ‘apache-hive-2.3.9-bin.tar.gz’ saved [286170958/286170958]

# %%
# !sed -i '1i export HADOOP_HOME=/content/hadoop-3.3.6' /content/apache-hive-2.3.9-bin/bin/hive
# !sed -i '1i export JAVA_HOME=/usr/lib/jvm/java-8-openjdk-amd64' /content/apache-hive-2.3.9-bin/bin/hive

# %%
# !/content/apache-hive-2.3.9-bin/bin/schematool -initSchema -dbType derby
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Metastore connection URL:	 jdbc:derby:;databaseName=metastore_db;create=true
# Metastore Connection Driver :	 org.apache.derby.jdbc.EmbeddedDriver
# Metastore connection User:	 APP
# Starting metastore schema initialization to 2.3.0
# Initialization script hive-schema-2.3.0.derby.sql
# Initialization script completed
# schemaTool completed

# %%
# commands

# CREATE TABLE emp1 (
#   eno INT,
#   ename STRING,
#   salary INT,
#   dno INT
# )
# ROW FORMAT DELIMITED
# FIELDS TERMINATED BY ','
# STORED AS TEXTFILE;



# LOAD DATA INPATH '/user/root/shiva/test1.txt' INTO TABLE emp1;

# %%
# !/content/apache-hive-2.3.9-bin/bin/hive
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-3.3.6/share/hadoop/common/lib/slf4j-reload4j-1.7.36.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
#
# Logging initialized using configuration in jar:file:/content/apache-hive-2.3.9-bin/lib/hive-common-2.3.9.jar!/hive-log4j2.properties Async: true
# Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# hive> CREATE TABLE emp1 (   eno INT,   ename STRING,   salary INT,   dno INT ) ROW FORMAT DELIMITED FIELDS TERMINATED BY ',' STORED AS TEXTFILE;
# OK
# ...
